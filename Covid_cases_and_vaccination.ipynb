# %%
import pandas as pd
# %matplotlib inline

# %%
url="https://covid.ourworldindata.org/data/owid-covid-data.csv"
df_country = pd.read_csv(url, sep=",")
df_country.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df_country['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df_India=df_country[df_country['location']=="India"]
df_India.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 84126      IND      Asia    India  2020-01-30          1.0        1.0
# 84127      IND      Asia    India  2020-01-31          1.0        0.0
# 84128      IND      Asia    India  2020-02-01          1.0        0.0
# 84129      IND      Asia    India  2020-02-02          2.0        1.0
# 84130      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 84126                 NaN           NaN         NaN                  NaN  ...
# 84127                 NaN           NaN         NaN                  NaN  ...
# 84128                 NaN           NaN         NaN                  NaN  ...
# 84129                 NaN           NaN         NaN                  NaN  ...
# 84130                 NaN           NaN         NaN                  NaN  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df_India=df_India.reset_index(drop=True)
df_India.head()
# Out:
#   iso_code continent location        date  total_cases  new_cases  \
# 0      IND      Asia    India  2020-01-30          1.0        1.0
# 1      IND      Asia    India  2020-01-31          1.0        0.0
# 2      IND      Asia    India  2020-02-01          1.0        0.0
# 3      IND      Asia    India  2020-02-02          2.0        1.0
# 4      IND      Asia    India  2020-02-03          3.0        1.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             1.9          20.6                   59.55
# ...

# %% [markdown]
# # Plotting Chart of Covid Cases

# %%
import plotly.express as px
fig=px.line(df_India, x="date", y="total_cases", title="Covid Cases")
fig.show()

# %%
b_India = df_country['location']=="India"
b_Germany = df_country['location']=="Germany"
b_Italy = df_country['location']=="Italy"

# %%
b_all = b_India|b_Germany|b_Italy
df_my_list = df_country[b_all]

# %%
fig=px.line(df_my_list, x="date", y="total_cases", color = "location", title="Covid Cases")
fig.show()

# %%
df_my_list['total_normal_cases']=df_my_list['total_cases']/df_my_list['population']
fig=px.line(df_my_list, x="date", y="total_normal_cases", color = "location", title="Covid Cases")
fig.update_layout(
    title="Relative cases overtime of Covid infectors",
    xaxis_title="Time",
    yaxis_title="Number of Cases",
    legend_title="Country",
    plot_bgcolor="#fdf9ed",
    font=dict(
        family="verdana",
        size=10,
        color="black"
    )
)
# fig.write_image("Covid_Cases.png")
fig.show()
# Out:
# /var/folders/dc/l2ls6f0542q6x629ltb1pc200000gn/T/ipykernel_11092/4254369330.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_country.fillna(0, inplace = True)

# %%
df_my_list['total_normal_vaccinations']=df_my_list['total_vaccinations']/df_my_list['population']
fig=px.line(df_my_list, x="date", y="total_normal_vaccinations", color = "location", title="Covid Vaccinations")
fig.update_layout(
    title="Relative vaccinations overtime",
    xaxis_title="Time",
    yaxis_title="Vaccinations",
    legend_title="Country",
    plot_bgcolor="#fdf9ed",
    font=dict(
        family="verdana",
        size=10,
        color="black"
    )
)
fig.show()
# fig.write_image("Covid_Vaccination.png")
# Out:
# /var/folders/dc/l2ls6f0542q6x629ltb1pc200000gn/T/ipykernel_11092/4292525039.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
